# %% [markdown]
# # First event inspection
#
# Load a GUNDAM engine and inspect the first event of the first model sample.

# %%
nCpuThreads = 3
gundamLibPath = "/Users/nadrino/Documents/Work/Install/gundam/lib"
workDir = "/Users/nadrino/Documents/Work/Output/results/gundam/GundamInputOA2024"
configPath = "configOA2024.yaml"
overrideList = [
    "override/v12ProdRun45.yaml",
    "override/onlyFlux5.yaml",
    "override/noEigen.yaml",
]
dataType = "Toy"  # "Asimov", "Toy", or "RealData"
seed = 12345

# %%
import sys
from pathlib import Path

import numpy as np

repoRoot = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
srcPath = repoRoot / "src"
if srcPath.exists() and str(srcPath) not in sys.path:
    sys.path.insert(0, str(srcPath))

from gundam_interface import GundamInterface, GundamLoader, GundamRuntime

# %%
np.random.seed(seed)

runtime = GundamRuntime(
    loader=GundamLoader(gundamLibPath=gundamLibPath),
    workDir=workDir,
    nCpuThreads=nCpuThreads,
    configPath=configPath,
    overrideList=overrideList,
    dataType=dataType,
    randomSeed=seed,
)

runtime.toDict(includeConfigJsonString=False)
# Out:
# {'nCpuThreads': 3,
#  'workDir': '/Users/nadrino/Documents/Work/Output/results/gundam/GundamInputOA2024',
#  'dataType': 'Toy',
#  'loader': {'moduleName': 'GUNDAM',
#   'gundamLibPath': '/Users/nadrino/Documents/Work/Install/gundam/lib'},
#  'randomSeed': 12345,
#  'configPath': 'configOA2024.yaml',
#  'overrideList': ['override/v12ProdRun45.yaml',
#   'override/onlyFlux5.yaml',
#   'override/noEigen.yaml']}

# %%
gundam = GundamInterface(runtime)
gundam.configure()
gundam.initialize()
# Out:
# 12345
# 2026.07.28 17:02:07  INFO ConfigUtils: Reading config file: /Users/nadrino/Documents/Work/Output/results/gundam/GundamInputOA2024/configOA2024.yaml
# 2026.07.28 17:02:07  INFO ConfigUtils: Overriding config with "/Users/nadrino/Documents/Work/Output/results/gundam/GundamInputOA2024/override/v12ProdRun45.yaml"
# 2026.07.28 17:02:07  WARN ConfigUtils:   Added: fitterEngineConfig/propagatorConfig/dataSetList/0(name:"ND280")/mc/filePathList
# 2026.07.28 17:02:07  WARN ConfigUtils:   Added: fitterEngineConfig/propagatorConfig/dataSetList/0(name:"ND280")/data/0(name:"data")/filePathList
# 2026.07.28 17:02:07  INFO ConfigUtils: Overriding config with "/Users/nadrino/Documents/Work/Output/results/gundam/GundamInputOA2024/override/onlyFlux5.yaml"
# 2026.07.28 17:02:07  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"Flux Systematics")/isEnabled: true -> false
# 2026.07.28 17:02:07  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"ND280 Detector Systematics (variations parameters)")/isEnabled: true -> false
# 2026.07.28 17:02:07  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"ND280 Detector Systematics (splined detector parameters)")/isEnabled: true -> false
# 2026.07.28 17:02:07  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"Cross-Section Systematics FSI parameters")/isEnabled: true -> false
# 2026.07.28 17:02:07  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"Cross-Section Systematics")/isEnabled: true -> false
# 2026.07.28 17:02:07  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"Cross-Section (binned) Systematics")/isEnabled: true -> false
# 2026.07.28 17:02:07  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/1(name:"Flux Systematics")/isEnabled: false -> true
# 2026.07.28 17:02:07  WARN ConfigUtils:   Added: fitterEngineConfig/propagatorConfig/parameterSetListConfig/1(name:"Flux Systematics")/enableOnlyParameters
# 2026.07.28 17:02:07  INFO ConfigUtils: Overriding config with "/Users/nadrino/Documents/Work/Output/results/gundam/GundamInputOA2024/override/noEigen.yaml"
# 2026.07.28 17:02:07  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"Flux Systematics")/useEigenDecompInFit: true -> false
# 2026.07.28 17:02:07  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"ND280 Detector Systematics (variations parameters)")/useEigenDecompInFit: true -> false
# 2026.07.28 17:02:07  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"ND280 Detector Systematics (splined detector parameters)")/useEigenDecompInFit: false -> false
# 2026.07.28 17:02:07  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"Cross-Section Systematics FSI parameters")/useEigenDecompInFit: true -> false
# 2026.07.28 17:02:07  WARN ConfigUtils:   Added: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"Cross-Section Systematics")/useEigenDecompInFit -> false
# 2026.07.28 17:02:07  WARN ConfigUtils:   Added: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"Cross-Section (binned) Systematics")/useEigenDecompInFit -> false
# 2026.07.28 17:02:08  WARN ConfigUtils: /fitterEngineConfig: key "allParamVariations" has been renamed. Use "paramVariationsSigmas" instead.
# 2026.07.28 17:02:08  WARN ConfigUtils: /fitterEngineConfig: key "scanConfig" has been renamed. Use "parameterScannerConfig" instead.
# 2026.07.28 17:02:08 ALERT ConfigUtils: /fitterEngineConfig: field "propagatorConfig" should be moved to: fitterEngineConfig/likelihoodInterfaceConfig/propagatorConfig
# 2026.07.28 17:02:08  WARN ConfigUtils: /fitterEngineConfig/minimizerConfig: key "max_iter" has been renamed. Use "maxIterations" instead.
# 2026.07.28 17:02:08  WARN ConfigUtils: /fitterEngineConfig/minimizerConfig: key "max_fcn" has been renamed. Use "maxFcnCalls" instead.
# 2026.07.28 17:02:08 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig: key "showEventBreakdownBeforePrior" has an invalid name. It won't be recognized by GUNDAM.
# 2026.07.28 17:02:08  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig: key "fitSampleSetConfig" has been renamed. Use "sampleSetConfig" instead.
# 2026.07.28 17:02:08 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig: field "parameterSetListConfig" should be moved to: parametersManagerConfig/parameterSetList
# 2026.07.28 17:02:08 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig: field "plotGeneratorConfig" should be moved to: likelihoodInterfaceConfig/plotGeneratorConfig
# 2026.07.28 17:02:08 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig: field "scanConfig" should be moved to: fitterEngineConfig/scanConfig
# 2026.07.28 17:02:08 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig: field "eventTreeWriter" should be moved to: likelihoodInterfaceConfig/eventTreeWriter
# 2026.07.28 17:02:08 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig: field "dataSetList" should be moved to: likelihoodInterfaceConfig/dataSetList
# 2026.07.28 17:02:08 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig/fitSampleSetConfig: key "dataEventType" has an invalid name. It won't be recognized by GUNDAM.
# 2026.07.28 17:02:08  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/fitSampleSetConfig: key "fitSampleList" has been renamed. Use "sampleList" instead.
# 2026.07.28 17:02:08 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig/fitSampleSetConfig: field "llhStatFunction" should be moved to: likelihoodInterfaceConfig/jointProbabilityConfig/type
# 2026.07.28 17:02:08 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig/fitSampleSetConfig: field "llhConfig" should be moved to: likelihoodInterfaceConfig/jointProbabilityConfig
# 2026.07.28 17:02:08  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/fitSampleSetConfig/fitSampleList/0: key "selectionCuts" has been renamed. Use "selectionCutStr" instead.
# 2026.07.28 17:02:08  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/0: key "covarianceMatrixFilePath" has been renamed. Use "parameterDefinitionFilePath" instead.
# 2026.07.28 17:02:08  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/0: key "covarianceMatrixTMatrixD" has been renamed. Use "covarianceMatrix" instead.
# 2026.07.28 17:02:08  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/0: key "useEigenDecompInFit" has been renamed. Use "enableEigenDecomp" instead.
# 2026.07.28 17:02:08 ALERT GenericToolbox.Root.h:119/<lambda>: Found a non-symmetric element m[0][6]: diff = -2.1684e-19
# 2026.07.28 17:02:08 ALERT GenericToolbox.Root.h:130/toTMatrixTSym: Conversion to symmetric matrix by averaging opposite elements...
# 2026.07.28 17:02:08 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/1: key "useOnlyOneParameterPerEvent" has an invalid name. It won't be recognized by GUNDAM.
# 2026.07.28 17:02:08  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/1: key "allowPca" has been renamed. Use "enablePca" instead.
# 2026.07.28 17:02:08  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/1: key "printDialSetsSummary" has been renamed. Use "printDialSetSummary" instead.
# 2026.07.28 17:02:08  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/1: key "parameterPriorTVectorD" has been renamed. Use "parameterPriorValueList" instead.
# 2026.07.28 17:02:08  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/1: key "eigenSvdThreshold" has been renamed. Use "eigenValueThreshold" instead.
# 2026.07.28 17:02:08 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/2: key "atLeastOneDialPerEvent" has an invalid name. It won't be recognized by GUNDAM.
# 2026.07.28 17:02:08  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/2: key "parameterNameTObjArray" has been renamed. Use "parameterNameList" instead.
# 2026.07.28 17:02:08  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/2: key "parameterLowerBoundsTVectorD" has been renamed. Use "parameterLowerBoundsList" instead.
# 2026.07.28 17:02:08  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/2: key "parameterUpperBoundsTVectorD" has been renamed. Use "parameterUpperBoundsList" instead.
# 2026.07.28 17:02:08  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/dataSetList/0: key "mc" has been renamed. Use "model" instead.
# 2026.07.28 17:02:08  WARN ConfigUtils:   Added: name -> "data"
# 2026.07.28 17:02:08  WARN ConfigUtils:   Added: tree -> "sample_sum"
# 2026.07.28 17:02:08  WARN ConfigUtils:   Added: filePathList
# 2026.07.28 17:02:08  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/plotGeneratorConfig: key "varDictionnaries" has been renamed. Use "varDictionaries" instead.
# 2026.07.28 17:02:08  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/plotGeneratorConfig/varDictionnaries/0/dictionary/0: key "color" has been renamed. Use "colorRoot" instead.
# 2026.07.28 17:02:08 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig/eventTreeWriter: key "dialWriterConfig" has an invalid name. It won't be recognized by GUNDAM.
# 2026.07.28 17:02:08  WARN EventTreeWriter: (virtual void EventTreeWriter::configureImpl()): Disabled EventTreeWriter.
# 2026.07.28 17:02:08 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig: key "showEventBreakdownBeforePrior" was ignored while parsing config. Is is context dependent option?
# 2026.07.28 17:02:08  INFO ParameterSet: Stripping the matrix from fixed/disabled parameters...
# 2026.07.28 17:02:08  INFO ParameterSet: 5 effective parameters were defined in set: Flux Systematics
# 2026.07.28 17:02:08  INFO ParameterSet: Computing inverse of the stripped covariance matrix: 5x5
# 2026.07.28 17:02:08  INFO ParametersManager: 5 enabled parameters in Flux Systematics
# 2026.07.28 17:02:08  INFO ParametersManager: Total number of parameters: 5
# 2026.07.28 17:02:08  INFO ParametersManager: Building global covariance matrix (5x5)
# 2026.07.28 17:02:08  INFO ParameterSet: Stripping the matrix from fixed/disabled parameters...
# 2026.07.28 17:02:08  INFO ParameterSet: 5 effective parameters were defined in set: Flux Systematics
# 2026.07.28 17:02:08  INFO ParameterSet: Computing inverse of the stripped covariance matrix: 5x5
# 2026.07.28 17:02:08  INFO ParametersManager: 5 enabled parameters in Flux Systematics
# 2026.07.28 17:02:08  INFO ParametersManager: Total number of parameters: 5
# 2026.07.28 17:02:08  INFO ParametersManager: Building global covariance matrix (5x5)
#
# 2026.07.28 17:02:08  INFO Propagator: Printing propagator configuration:
# 2026.07.28 17:02:08  INFO SampleSet: 32 samples are defined:
# ┌──────────────────────────────────────────────────────────┬───────────────────────┬────────────┐
# │                                                     Name │             Selection │ Nb of bins │
# ├──────────────────────────────────────────────────────────┼───────────────────────┼────────────┤
# │                FHC FGD1 #nu_{#mu} CC 0#pi 0p 0#gamma Fwd │ SelectedSample == 131 │        252 │
# │                FHC FGD1 #nu_{#mu} CC 0#pi Np 0#gamma Fwd │ SelectedSample == 132 │        224 │
# │                  FGD1 numuCC 0#pi 0#gamma No Protons Bwd │ SelectedSample == 133 │         30 │
# │               FGD1 numuCC 0#pi Bwd 0#gamma N Protons Bwd │ SelectedSample == 134 │         60 │
# │                   FGD1 numuCC 0#pi 0#gamma No Protons HA │ SelectedSample == 139 │         96 │
# │                    FGD1 numuCC 0#pi 0#gamma N Protons HA │ SelectedSample == 140 │        102 │
# │                   FHC FGD1 #nu_{#mu} CC 1#pi 0#gamma Fwd │ SelectedSample == 116 │        140 │
# │                            FGD1 numuCC 1Pi 0#gamma HAFwd │ SelectedSample == 122 │         30 │
# │                      FHC FGD1 #nu_{#mu} CC Other 0#gamma │ SelectedSample == 117 │        144 │
# │                             FHC FGD1 #nu_{#mu} CC #gamma │ SelectedSample == 127 │        182 │
# │                FHC FGD2 #nu_{#mu} CC 0#pi 0p 0#gamma Fwd │ SelectedSample == 157 │        252 │
# │                FHC FGD2 #nu_{#mu} CC 0#pi Np 0#gamma Fwd │ SelectedSample == 158 │        168 │
# │                  FGD2 numuCC 0#pi 0#gamma No Protons Bwd │ SelectedSample == 159 │         18 │
# │                   FGD2 numuCC 0#pi 0#gamma N Protons Bwd │ SelectedSample == 160 │         54 │
# │                   FGD2 numuCC 0#pi HA 0#gamma No Protons │ SelectedSample == 165 │        100 │
# │                    FGD2 numuCC 0#pi 0#gamma N Protons HA │ SelectedSample == 166 │         78 │
# │                   FHC FGD2 #nu_{#mu} CC 1#pi 0#gamma Fwd │ SelectedSample == 142 │        160 │
# │                            FGD2 numuCC 1Pi 0#gamma HAFwd │ SelectedSample == 148 │         30 │
# │                      FHC FGD2 #nu_{#mu} CC Other 0#gamma │ SelectedSample == 143 │        152 │
# │                             FHC FGD2 #nu_{#mu} CC #gamma │ SelectedSample == 153 │        153 │
# │                          RHC FGD1 Anti #nu_{#mu} CC 0#pi │  SelectedSample == 59 │        240 │
# │                          RHC FGD1 Anti #nu_{#mu} CC 1#pi │  SelectedSample == 60 │        110 │
# │                         RHC FGD1 Anti #nu_{#mu} CC Other │  SelectedSample == 61 │        110 │
# │                          RHC FGD2 Anti #nu_{#mu} CC 0#pi │  SelectedSample == 69 │        242 │
# │                          RHC FGD2 Anti #nu_{#mu} CC 1#pi │  SelectedSample == 70 │         88 │
# │                         RHC FGD2 Anti #nu_{#mu} CC Other │  SelectedSample == 71 │         88 │
# │   RHC FGD1 #nu_{#mu} (background) CC 0#pi in AntiNu_Mode │  SelectedSample == 79 │        210 │
# │   RHC FGD1 #nu_{#mu} (background) CC 1#pi in AntiNu_Mode │  SelectedSample == 80 │        126 │
# │  RHC FGD1 #nu_{#mu} (background) CC Other in AntiNu_Mode │  SelectedSample == 81 │        126 │
# │   RHC FGD2 #nu_{#mu} (background) CC 0#pi in AntiNu_Mode │  SelectedSample == 85 │        182 │
# │  RHC FGD2 #nu_{#mu} (background) CC 1#pi  in AntiNu_Mode │  SelectedSample == 86 │         88 │
# │ RHC FGD2 #nu_{#mu} (background) CC Other  in AntiNu_Mode │  SelectedSample == 87 │        105 │
# └──────────────────────────────────────────────────────────┴───────────────────────┴────────────┘
# 2026.07.28 17:02:08  INFO ParametersManager: 1 parameter sets defined.
# 2026.07.28 17:02:08  INFO ParameterSet: Flux Systematics has 5 defined parameters:
# ┌───────┬───────┬──────────┬──────────────┐
# │ Title │ Prior │   StdDev │       Limits │
# ├───────┼───────┼──────────┼──────────────┤
# │    #0 │     1 │ 0.059244 │ [-inf, +inf] │
# │    #1 │     1 │ 0.052535 │ [-inf, +inf] │
# │    #2 │     1 │ 0.052934 │ [-inf, +inf] │
# │    #3 │     1 │ 0.051455 │ [-inf, +inf] │
# │    #4 │     1 │ 0.073820 │ [-inf, +inf] │
# └───────┴───────┴──────────┴──────────────┘
# 2026.07.28 17:02:08  INFO DialManager: Dial manager has 1 dial collections:
# ┌──────────────────┬──────┬─────────┐
# │  Dial Collection │ Type │ Options │
# ├──────────────────┼──────┼─────────┤
# │ Flux Systematics │ Norm │         │
# └──────────────────┴──────┴─────────┘
# 2026.07.28 17:02:08  INFO DialManager:       : Event-by-event dials.
#
#
# 2026.07.28 17:02:08  INFO LikelihoodInterface: Loading model...
# 2026.07.28 17:02:08  INFO LikelihoodInterface: Loading datasets...
# 2026.07.28 17:02:08  INFO DataDispenser: Loading dataset: ND280/Asimov
# 2026.07.28 17:02:08  INFO DataDispenser: Fetching samples to fill...
# 2026.07.28 17:02:08  INFO DataDispenser: Variable dictionary: {
# 2026.07.28 17:02:08  INFO DataDispenser:   { Pmu: PmuAdjusted }
# 2026.07.28 17:02:08  INFO DataDispenser: }
# 2026.07.28 17:02:08  INFO DataDispenser: Poll all objects for requested variables...
# 2026.07.28 17:02:08  INFO DataDispenser: Selecting dial collections...
# 2026.07.28 17:02:08  INFO DataDispenser: DialCollection requests for indexing: { "isRHC", "NeutrinoCode", "Enu" }
# 2026.07.28 17:02:08  INFO DataDispenser: Samples variable request for indexing: { "CosThetamu", "Pmu" }
# 2026.07.28 17:02:08  INFO DataDispenser: PlotGenerator variable request for storage: { "Pmu", "CosThetamu", "ReactionCode" }
# 2026.07.28 17:02:08  INFO DataDispenser: Additional var requests for storage:{ }
# 2026.07.28 17:02:08  INFO DataDispenser: Vars requested for storage: { "Pmu", "CosThetamu", "ReactionCode" }
# 2026.07.28 17:02:08  INFO DataDispenser: Performing event selection...
# 2026.07.28 17:02:08  INFO DataDispenser: Event selection...
# 2026.07.28 17:02:08  INFO DataDispenser: Opening ROOT files containing events...
# 2026.07.28 17:02:08  INFO DataDispenser:   /Users/nadrino/Documents/Work/Output/results/gundam/common/OA2024/ND280/Inputs/Splines/XSecAndNDSyst/P7/v12_Highland_3.22.4/MC_mirrored/run4wMCsplines.root
# 2026.07.28 17:02:08  INFO DataDispenser:   /Users/nadrino/Documents/Work/Output/results/gundam/common/OA2024/ND280/Inputs/Splines/XSecAndNDSyst/P7/v12_Highland_3.22.4/MC_mirrored/run5MCsplines.root
# 2026.07.28 17:02:08  INFO DataDispenser:   /Users/nadrino/Documents/Work/Output/results/gundam/common/OA2024/ND280/Inputs/Splines/XSecAndNDSyst/P7/v12_Highland_3.22.4/Sand/runFHCsand4wSplines.root
# 2026.07.28 17:02:08  INFO DataDispenser:   /Users/nadrino/Documents/Work/Output/results/gundam/common/OA2024/ND280/Inputs/Splines/XSecAndNDSyst/P7/v12_Highland_3.22.4/Sand/runRHCsand5Splines.root
# 2026.07.28 17:02:08  INFO DataDispenser: Will read 455803 event entries.
# 2026.07.28 17:02:08  INFO DataDispenser: Selection variable requests: { "passedPsyche", "isConsecutiveIdenticalEvent", "SelectedSample" }
# 2026.07.28 17:02:08  INFO DataDispenser: Global selection cut: "((passedPsyche * (!isConsecutiveIdenticalEvent)))"
# 2026.07.28 17:02:08  INFO DataDispenser: Read from disk:      27B (  6.75KB/s) / CPU efficiency:  38%
# 2026.07.28 17:02:08  INFO DataDispenser: Performing event selection on ND280/Asimov...   0% (    2 it/s)
#
# 2026.07.28 17:02:08  INFO DataDispenser: Read from disk: 347.436K (10.5275M/s) / CPU efficiency: 100%
# 2026.07.28 17:02:08  INFO DataDispenser: Performing event selection on ND280/Asimov...   8% (1169K it/s)
#
# 2026.07.28 17:02:08  INFO DataDispenser: Read from disk: 741.798K (11.9504M/s) / CPU efficiency: 122%
# 2026.07.28 17:02:08  INFO DataDispenser: Performing event selection on ND280/Asimov...  18% (1327K it/s)
#
# 2026.07.28 17:02:08  INFO DataDispenser: Read from disk: 1.1333MB (11.8636M/s) / CPU efficiency:  83%
# 2026.07.28 17:02:08  INFO DataDispenser: Performing event selection on ND280/Asimov...  28% (1318K it/s)
#
# 2026.07.28 17:02:08  INFO DataDispenser: Read from disk: 1.5275MB (11.9455M/s) / CPU efficiency: 100%
# 2026.07.28 17:02:08  INFO DataDispenser: Performing event selection on ND280/Asimov...  37% (1327K it/s)
#
# 2026.07.28 17:02:08  INFO DataDispenser: Read from disk: 1.91103M (11.6223M/s) / CPU efficiency: 111%
# 2026.07.28 17:02:08  INFO DataDispenser: Performing event selection on ND280/Asimov...  47% (1291K it/s)
#
# 2026.07.28 17:02:08  INFO DataDispenser: Read from disk: 2.3021MB (11.8505M/s) / CPU efficiency:  83%
# 2026.07.28 17:02:08  INFO DataDispenser: Performing event selection on ND280/Asimov...  56% (1316K it/s)
#
# 2026.07.28 17:02:08  INFO DataDispenser: Read from disk: 2.69625M (11.9438M/s) / CPU efficiency: 100%
# 2026.07.28 17:02:08  INFO DataDispenser: Performing event selection on ND280/Asimov...  66% (1327K it/s)
#
# 2026.07.28 17:02:08  INFO DataDispenser: Read from disk: 3.09253M (12.0085M/s) / CPU efficiency: 111%
# 2026.07.28 17:02:08  INFO DataDispenser: Performing event selection on ND280/Asimov...  75% (1334K it/s)
#
# 2026.07.28 17:02:08  INFO DataDispenser: Read from disk: 3.51359M (12.7595M/s) / CPU efficiency:  91%
# 2026.07.28 17:02:08  INFO DataDispenser: Performing event selection on ND280/Asimov...  86% (1417K it/s)
#
# 2026.07.28 17:02:08  INFO DataDispenser: Read from disk: 3.93271M (12.7006M/s) / CPU efficiency: 100%
# 2026.07.28 17:02:08  INFO DataDispenser: Performing event selection on ND280/Asimov...  96% (1411K it/s)
#
# 2026.07.28 17:02:08  INFO DataDispenser: Read from disk: 4.10224M (13.041MB/s) / CPU efficiency:  66%
# 2026.07.28 17:02:08  INFO DataDispenser: Performing event selection on ND280/Asimov... 100% (1449K it/s)
# 2026.07.28 17:02:08  INFO DataDispenser: Merging thread results...
# 2026.07.28 17:02:08  INFO DataDispenser: Freeing up thread buffers...
# 2026.07.28 17:02:08  INFO DataDispenser: Events passing selection cuts:
# ┌──────────────────────────────────────────────────────────┬───────────────────────┬─────────────┐
# │                                                   Sample │             Selection │ # of events │
# ├──────────────────────────────────────────────────────────┼───────────────────────┼─────────────┤
# │                FHC FGD1 #nu_{#mu} CC 0#pi 0p 0#gamma Fwd │ SelectedSample == 131 │       69198 │
# │                FHC FGD1 #nu_{#mu} CC 0#pi Np 0#gamma Fwd │ SelectedSample == 132 │       27487 │
# │                  FGD1 numuCC 0#pi 0#gamma No Protons Bwd │ SelectedSample == 133 │        2329 │
# │               FGD1 numuCC 0#pi Bwd 0#gamma N Protons Bwd │ SelectedSample == 134 │        1889 │
# │                   FGD1 numuCC 0#pi 0#gamma No Protons HA │ SelectedSample == 139 │        8668 │
# │                    FGD1 numuCC 0#pi 0#gamma N Protons HA │ SelectedSample == 140 │        6528 │
# │                   FHC FGD1 #nu_{#mu} CC 1#pi 0#gamma Fwd │ SelectedSample == 116 │       18408 │
# │                            FGD1 numuCC 1Pi 0#gamma HAFwd │ SelectedSample == 122 │        1500 │
# │                      FHC FGD1 #nu_{#mu} CC Other 0#gamma │ SelectedSample == 117 │        3359 │
# │                             FHC FGD1 #nu_{#mu} CC #gamma │ SelectedSample == 127 │       38945 │
# │                FHC FGD2 #nu_{#mu} CC 0#pi 0p 0#gamma Fwd │ SelectedSample == 157 │       72819 │
# │                FHC FGD2 #nu_{#mu} CC 0#pi Np 0#gamma Fwd │ SelectedSample == 158 │       20536 │
# │                  FGD2 numuCC 0#pi 0#gamma No Protons Bwd │ SelectedSample == 159 │        1739 │
# │                   FGD2 numuCC 0#pi 0#gamma N Protons Bwd │ SelectedSample == 160 │         821 │
# │                   FGD2 numuCC 0#pi HA 0#gamma No Protons │ SelectedSample == 165 │        8089 │
# │                    FGD2 numuCC 0#pi 0#gamma N Protons HA │ SelectedSample == 166 │        3788 │
# │                   FHC FGD2 #nu_{#mu} CC 1#pi 0#gamma Fwd │ SelectedSample == 142 │       14651 │
# │                            FGD2 numuCC 1Pi 0#gamma HAFwd │ SelectedSample == 148 │         908 │
# │                      FHC FGD2 #nu_{#mu} CC Other 0#gamma │ SelectedSample == 143 │        3254 │
# │                             FHC FGD2 #nu_{#mu} CC #gamma │ SelectedSample == 153 │       36076 │
# │                          RHC FGD1 Anti #nu_{#mu} CC 0#pi │  SelectedSample == 59 │       26759 │
# │                          RHC FGD1 Anti #nu_{#mu} CC 1#pi │  SelectedSample == 60 │        2042 │
# │                         RHC FGD1 Anti #nu_{#mu} CC Other │  SelectedSample == 61 │        3881 │
# │                          RHC FGD2 Anti #nu_{#mu} CC 0#pi │  SelectedSample == 69 │       26325 │
# │                          RHC FGD2 Anti #nu_{#mu} CC 1#pi │  SelectedSample == 70 │        1914 │
# │                         RHC FGD2 Anti #nu_{#mu} CC Other │  SelectedSample == 71 │        3598 │
# │   RHC FGD1 #nu_{#mu} (background) CC 0#pi in AntiNu_Mode │  SelectedSample == 79 │        8786 │
# │   RHC FGD1 #nu_{#mu} (background) CC 1#pi in AntiNu_Mode │  SelectedSample == 80 │        3059 │
# │  RHC FGD1 #nu_{#mu} (background) CC Other in AntiNu_Mode │  SelectedSample == 81 │        2732 │
# │   RHC FGD2 #nu_{#mu} (background) CC 0#pi in AntiNu_Mode │  SelectedSample == 85 │        8901 │
# │  RHC FGD2 #nu_{#mu} (background) CC 1#pi  in AntiNu_Mode │  SelectedSample == 86 │        2489 │
# │ RHC FGD2 #nu_{#mu} (background) CC Other  in AntiNu_Mode │  SelectedSample == 87 │        2680 │
# ├──────────────────────────────────────────────────────────┼───────────────────────┼─────────────┤
# │                                                    Total │                       │      434158 │
# └──────────────────────────────────────────────────────────┴───────────────────────┴─────────────┘
# 2026.07.28 17:02:08  INFO DataDispenser: Pre-allocating memory...
# 2026.07.28 17:02:08  INFO DataDispenser: Reserving event memory...
# ┌──────────────────────────────────────────────────────────┬─────────────┬───────────┐
# │                                                   Sample │ # of events │    Memory │
# ├──────────────────────────────────────────────────────────┼─────────────┼───────────┤
# │                FHC FGD1 #nu_{#mu} CC 0#pi 0p 0#gamma Fwd │       69198 │ 11.9021MB │
# │                FHC FGD1 #nu_{#mu} CC 0#pi Np 0#gamma Fwd │       27487 │ 4.72776MB │
# │                  FGD1 numuCC 0#pi 0#gamma No Protons Bwd │        2329 │ 400.588KB │
# │               FGD1 numuCC 0#pi Bwd 0#gamma N Protons Bwd │        1889 │ 324.908KB │
# │                   FGD1 numuCC 0#pi 0#gamma No Protons HA │        8668 │  1.4909MB │
# │                    FGD1 numuCC 0#pi 0#gamma N Protons HA │        6528 │ 1.12282MB │
# │                   FHC FGD1 #nu_{#mu} CC 1#pi 0#gamma Fwd │       18408 │ 3.16618MB │
# │                            FGD1 numuCC 1Pi 0#gamma HAFwd │        1500 │     258KB │
# │                      FHC FGD1 #nu_{#mu} CC Other 0#gamma │        3359 │ 577.748KB │
# │                             FHC FGD1 #nu_{#mu} CC #gamma │       38945 │ 6.69854MB │
# │                FHC FGD2 #nu_{#mu} CC 0#pi 0p 0#gamma Fwd │       72819 │ 12.5249MB │
# │                FHC FGD2 #nu_{#mu} CC 0#pi Np 0#gamma Fwd │       20536 │ 3.53219MB │
# │                  FGD2 numuCC 0#pi 0#gamma No Protons Bwd │        1739 │ 299.108KB │
# │                   FGD2 numuCC 0#pi 0#gamma N Protons Bwd │         821 │ 141.212KB │
# │                   FGD2 numuCC 0#pi HA 0#gamma No Protons │        8089 │ 1.39131MB │
# │                    FGD2 numuCC 0#pi 0#gamma N Protons HA │        3788 │ 651.536KB │
# │                   FHC FGD2 #nu_{#mu} CC 1#pi 0#gamma Fwd │       14651 │ 2.51997MB │
# │                            FGD2 numuCC 1Pi 0#gamma HAFwd │         908 │ 156.176KB │
# │                      FHC FGD2 #nu_{#mu} CC Other 0#gamma │        3254 │ 559.688KB │
# │                             FHC FGD2 #nu_{#mu} CC #gamma │       36076 │ 6.20507MB │
# │                          RHC FGD1 Anti #nu_{#mu} CC 0#pi │       26759 │ 4.60255MB │
# │                          RHC FGD1 Anti #nu_{#mu} CC 1#pi │        2042 │ 351.224KB │
# │                         RHC FGD1 Anti #nu_{#mu} CC Other │        3881 │ 667.532KB │
# │                          RHC FGD2 Anti #nu_{#mu} CC 0#pi │       26325 │  4.5279MB │
# │                          RHC FGD2 Anti #nu_{#mu} CC 1#pi │        1914 │ 329.208KB │
# │                         RHC FGD2 Anti #nu_{#mu} CC Other │        3598 │ 618.856KB │
# │   RHC FGD1 #nu_{#mu} (background) CC 0#pi in AntiNu_Mode │        8786 │ 1.51119MB │
# │   RHC FGD1 #nu_{#mu} (background) CC 1#pi in AntiNu_Mode │        3059 │ 526.148KB │
# │  RHC FGD1 #nu_{#mu} (background) CC Other in AntiNu_Mode │        2732 │ 469.904KB │
# │   RHC FGD2 #nu_{#mu} (background) CC 0#pi in AntiNu_Mode │        8901 │ 1.53097MB │
# │  RHC FGD2 #nu_{#mu} (background) CC 1#pi  in AntiNu_Mode │        2489 │ 428.108KB │
# │ RHC FGD2 #nu_{#mu} (background) CC Other  in AntiNu_Mode │        2680 │  460.96KB │
# ├──────────────────────────────────────────────────────────┼─────────────┼───────────┤
# │                                                    Total │      434158 │ 74.6752MB │
# └──────────────────────────────────────────────────────────┴─────────────┴───────────┘
# 2026.07.28 17:02:08  INFO DataDispenser: Filling var index cache for bin edges...
# 2026.07.28 17:02:08  INFO DataDispenser: Reading dataset and loading...
# 2026.07.28 17:02:08  INFO DataDispenser: Nominal weight: "((FluxWeight[0] * PileUpWeight)*(POTWeight)*((DetNomWeight > 10) ? 10: (DetNomWeight < 0 ? 0 : DetNomWeight))*(XsecNomWeight))"
# 2026.07.28 17:02:08  INFO DataDispenser: Loading and indexing...
# 2026.07.28 17:02:08  INFO DataDispenser: Feeding event variables with:
# ┌─────────────────────────────┬───────────────────────────────┐
# │                    Variable │                    Expression │
# ├─────────────────────────────┼───────────────────────────────┤
# │ isConsecutiveIdenticalEvent │ isConsecutiveIdenticalEvent/B │
# │                NeutrinoCode │                NeutrinoCode/I │
# │                ReactionCode │                ReactionCode/I │
# │              SelectedSample │              SelectedSample/I │
# │                       isRHC │                       isRHC/I │
# │                passedPsyche │                passedPsyche/I │
# │                  CosThetamu │                  CosThetamu/D │
# │                DetNomWeight │                DetNomWeight/D │
# │                         Enu │                         Enu/D │
# │                   POTWeight │                   POTWeight/D │
# │                PileUpWeight │                PileUpWeight2026.07.28 17:02:08/D ALERT [ │
# │  90mD   ata    Dispenser: Select        PmuAed djusevented │ t n   ot     in a    li      PmuAdjusted/D �kel��
# │               XsecNomWeight │               XsecNomWeight/D │
# │                         Pmu │ihoo           PmuAdjusted/formula │
# └───d h─ist─────────────────────────┴───────────────────────────────┘
# ogram bin:
# 2026.07.28 17:02:08 ALERT DataDispenser:   Indices{dataset(0), entry(152204 / 0-152204), sample(0), bin(-1)}
# 2026.07.28 17:02:08 ALERT DataDispenser:   Weights{base(0.0577043), current(1)}
# 2026.07.28 17:02:08 ALERT DataDispenser:   Variables used in binning{ CosThetamu: 0.997801, Pmu: 102593, }
# 2026.07.28 17:02:08  INFO DataDispenser:        -> Variables stored in RAM
# 2026.07.28 17:02:08 ALERT DataDispenser: Selected event not in a likelihood histogram bin:
# 2026.07.28 17:02:08 ALERT DataDispenser:   Indices{dataset(0), entry(304005 / 0-304005), sample(10), bin(-1)}
# 2026.07.28 17:02:08 ALERT DataDispenser:   Weights{base(0.0699243), current(1)}
# 2026.07.28 17:02:08 ALERT DataDispenser:   Variables used in binning{ CosThetamu: 0.964861, Pmu: 32316.4, }
# 2026.07.28 17:02:08  INFO DataDispenser: Reading from disk:     267B (33.375KB/202s6) .07.2/ CPU effic8i 17e:0ncy: 2:08  5[0% 35/ mARLERAM:T[0 586.36m 7MB
# 2026.Dat07.28 aD17ispens:er02[0:0m: 8Selected [3 even2t nom INFO t i[9n a likelih0mDaootd haDiistograspm bin:
# enser20: Data .size07.28 per  17:entry: 02:08 2 5/ mAUsing 3LE RthrT eads
# 20DataDisp26.en07se.2r[08 17:02:m:08    In[32dim INFces{dataO0et(0)m DataDispenser: Loading and inde, exinntrg..y(152409 / 0-152409), sample(10), bin(-1)}
# .2026.07.28 17:02:08 ALERT DataDispenser:   Weights{base(0.0560135), current(1)}
#  202  0% (    0 it/s)
#
# 6.07.28 17:02:08 ALERT DataDispenser:   Variables used in binning{ CosThetamu: 0.999738, Pmu: 67678.5, }
# 2026.07.28 17:02:08 ALERT DataDispenser: Selected event not in a likelihood histogram bin:
# 2026.07.28 17:02:08 ALERT DataDispenser:   Indices{dataset(0), entry(304209 / 0-304209), sample(14), bin(-1)}
# 2026.07.28 17:02:08 ALERT DataDispenser:   Weights{base(0.0519576), current(1)}
# 2026.07.28 17:02:08 ALERT DataDispenser:   Variables used in binning{ CosThetamu: 0.898291, Pmu: 129451, }
# 2026.07.28 17:02:08 ALERT DataDispenser: Selected event not in a likelihood histogram bin:
# 2026.07.28 17:02:08 ALERT DataDispenser:   Indices{dataset(0), entry(154 / 0-154), sample(1), bin(-1)}
# 2026.07.28 17:02:08 ALERT DataDispenser:   Weights{base(0.0479617), current(1)}
# 2026.07.28 17:02:08 ALERT DataDispenser:   Variables used in binning{ CosThetamu: 0.986233, Pmu: 163602, }
# 2026.07.28 17:02:08  INFO DataDispenser: Reading from disk: 449.094K (13.6008M/s) / CPU efficiency:  83% / RAM: 586.367MB
# 2026.07.28 17:02:08  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:08  INFO DataDispenser: Loading and indexing...   1% ( 161K it/s)
#
# 2026.07.28 17:02:08  INFO DataDispenser: Reading from disk: 925.155K (14.4261M/s) / CPU efficiency: 122% / RAM: 598.065MB
# 2026.07.28 17:02:08  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:08  INFO DataDispenser: Loading and indexing...   2% ( 170K it/s)
#
# 2026.07.28 17:02:08  INFO DataDispenser: Reading from disk: 1.54139M (18.6738M/s) / CPU efficiency: 133% / RAM: 598.344MB
# 2026.07.28 17:02:08  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:08  INFO DataDispenser: Loading and indexing...   4% ( 222K it/s)
#
# 2026.07.28 17:02:08  INFO DataDispenser: Reading from disk: 2.1085MB (17.1851M/s) / CPU efficiency: 108% / RAM: 598.622MB
# 2026.07.28 17:02:08  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:08  INFO DataDispenser: Loading and indexing...   5% ( 205K it/s)
#
# 2026.07.28 17:02:08  INFO DataDispenser: Reading from disk: 2.76238M (19.8146M/s) / CPU efficiency: 133% / RAM: 598.655MB
# 2026.07.28 17:02:08  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:08  INFO DataDispenser: Loading and indexing...   7% ( 235K it/s)
#
# 2026.07.28 17:02:09  INFO DataDispenser: Reading from disk: 3.42161M (19.9765M/s) / CPU efficiency: 133% / RAM: 598.802MB
# 2026.07.28 17:02:09  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:09  INFO DataDispenser: Loading and indexing...   9% ( 237K it/s)
#
# 2026.07.28 17:02:09  INFO DataDispenser: Reading from disk: 4.11634M (21.0525M/s) / CPU efficiency: 133% / RAM: 599.048MB
# 2026.07.28 17:02:09  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:09  INFO DataDispenser: Loading and indexing...  11% ( 249K it/s)
#
# 2026.07.28 17:02:09  INFO DataDispenser: Reading from disk: 4.76248M ( 19.58MB/s) / CPU efficiency: 100% / RAM: 599.704MB
# 2026.07.28 17:02:09  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:09  INFO DataDispenser: Loading and indexing...  12% ( 231K it/s)
#
# 2026.07.28 17:02:09  INFO DataDispenser: Reading from disk: 5.43959M (20.5185M/s) / CPU efficiency: 133% / RAM: 599.704MB
# 2026.07.28 17:02:09  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:09  INFO DataDispenser: Loading and indexing...  14% ( 243K it/s)
#
# 2026.07.28 17:02:09  INFO DataDispenser: Reading from disk: 6.14794M (21.4652M/s) / CPU efficiency: 144% / RAM: 599.785MB
# 2026.07.28 17:02:09  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:09  INFO DataDispenser: Loading and indexing...  16% ( 255K it/s)
#
# 2026.07.28 17:02:09  INFO DataDispenser: Reading from disk:
B
# 2026.07.28 17:02:10  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:10  INFO DataDispenser: Loading and indexing...  67% ( 262K it/s)
#
# 2026.07.28 17:02:10  INFO DataDispenser: Reading from disk: 26.4138M (21.4166M/s) / CPU efficiency: 133% / RAM: 602.8MB
# 2026.07.28 17:02:10  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:10  INFO DataDispenser: Loading and indexing...  69% ( 253K it/s)
#
# 2026.07.28 17:02:10  INFO DataDispenser: Reading from disk: 27.0362M (18.8599M/s) / CPU efficiency: 133% / RAM: 603.046MB
# 2026.07.28 17:02:10  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:10  INFO DataDispenser: Loading and indexing...  70% ( 223K it/s)
#
# 2026.07.28 17:02:10  INFO DataDispenser: Reading from disk: 27.7498M (21.627MB/s) / CPU efficiency: 133% / RAM: 603.21MB
# 2026.07.28 17:02:10  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:10  INFO DataDispenser: Loading and indexing...  72% ( 255K it/s)
#
# 2026.07.28 17:02:10  INFO DataDispenser: Reading from disk: 28.4101M (20.0088M/s) / CPU efficiency: 100% / RAM: 603.259MB
# 2026.07.28 17:02:10  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:10  INFO DataDispenser: Loading and indexing...  74% ( 238K it/s)
#
# 2026.07.28 17:02:10  INFO DataDispenser: Reading from disk: 29.0824M (20.3729M/s) / CPU efficiency: 144% / RAM: 603.488MB
# 2026.07.28 17:02:10  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:10  INFO DataDispenser: Loading and indexing...  76% ( 242K it/s)
#
# 2026.07.28 17:02:10  INFO DataDispenser: Reading from disk: 29.7096M (18.4466M/s) / CPU efficiency:  91% / RAM: 603.668MB
# 2026.07.28 17:02:10  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:10  INFO DataDispenser: Loading and indexing...  77% ( 218K it/s)
#
# 2026.07.28 17:02:10  INFO DataDispenser: Reading from disk: 29.7766M (2.03082M/s) / CPU efficiency:  22% / RAM: 603.718MB
# 2026.07.28 17:02:10  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:10  INFO DataDispenser: Loading and indexing...  78% (  24K it/s)
#
# 2026.07.28 17:02:10  INFO DataDispenser: Reading from disk: 30.2952M (15.7125M/s) / CPU efficiency: 122% / RAM: 604.013MB
# 2026.07.28 17:02:10  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:10  INFO DataDispenser: Loading and indexing...  79% ( 187K it/s)
#
# 2026.07.28 17:02:10  INFO DataDispenser: Reading from disk: 30.9725M (20.5266M/s) / CPU efficiency: 133% / RAM: 604.226MB
# 2026.07.28 17:02:10  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:10  INFO DataDispenser: Loading and indexing...  81% ( 242K it/s)
#
# 2026.07.28 17:02:10  INFO DataDispenser: Reading from disk: 31.6734M (21.2386M/s) / CPU efficiency: 100% / RAM: 604.439MB
# 2026.07.28 17:02:10  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:10  INFO DataDispenser: Loading and indexing...  82% ( 252K it/s)
#
# 2026.07.28 17:02:10  INFO DataDispenser: Reading from disk: 32.3059M (19.1674M/s) / CPU efficiency: 144% / RAM: 604.652MB
# 2026.07.28 17:02:10  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:10  INFO DataDispenser: Loading and indexing...  84% ( 226K it/s)
#
# 2026.07.28 17:02:10  INFO DataDispenser: Reading from disk: 32.9601M (19.8227M/s) / CPU efficiency: 133% / RAM: 604.881MB
# 2026.07.28 17:02:10  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:10  INFO DataDispenser: Loading and indexing...  86% ( 235K it/s)
#
# 2026.07.28 17:02:10  INFO DataDispenser: Reading from disk: 33.6148M (19.8389M/s) / CPU efficiency: 100% / RAM: 605.028MB
# 2026.07.28 17:02:10  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:10  INFO DataDispenser: Loading and indexing...  87% ( 234K it/s)
#
# 2026.07.28 17:02:10  INFO DataDispenser: Reading from disk: 34.2649M (19.7014M/s) / CPU efficiency: 122% / RAM: 605.356MB
# 2026.07.28 17:02:10  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:10  INFO DataDispenser: Loading and indexing...  89% ( 233K it/s)
#
# 2026.07.28 17:02:10  INFO DataDispenser: Reading from disk: 34.9319M (20.2111M/s) / CPU efficiency: 133% / RAM: 605.52MB
# 2026.07.28 17:02:10  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# 2026.07.28 17:02:10  INFO DataDispenser: Loading and indexing...  91% ( 239K it/s)
#
# 2026.07.28 17:02:10  INFO DataDispenser: Reading from disk: 35.4074M (14.4099M/s) / CPU efficiency:  91% / RAM: 605.585MB
# 2026.07.28 17:02:10  INFO DataDispenser: Data size per entry: 267B / Using 3 threads
# ...
# │        #1 │ 1.000000 │ 0.052535 │ [-inf, +inf] │ 1.046929 │
# │        #2 │ 1.000000 │ 0.052934 │ [-inf, +inf] │ 1.027865 │
# │        #3 │ 1.000000 │ 0.051455 │ [-inf, +inf] │ 0.980247 │
# │        #4 │ 1.000000 │ 0.073820 │ [-inf, +inf] │ 0.937612 │
# └───────────┴──────────┴──────────┴──────────────┴──────────┘
# 2026.07.28 17:02:11  INFO LikelihoodInterface: Copying events from the model...
# 2026.07.28 17:02:11  INFO LikelihoodInterface: Filling up data sample bin caches...
# 2026.07.28 17:02:11  INFO LikelihoodInterface: Updating sample per bin event lists...
# 2026.07.28 17:02:11  INFO LikelihoodInterface: Filling up data sample histograms...
# 2026.07.28 17:02:11  INFO LikelihoodInterface: Throwing statistical error...
# 2026.07.28 17:02:11  INFO LikelihoodInterface: enableEventMcThrow is enabled: throwing individual MC events
# 2026.07.28 17:02:11  INFO LikelihoodInterface: Throwing statistical error on histograms...
#
# 2026.07.28 17:02:11  INFO Propagator: Breaking down samples...
# 2026.07.28 17:02:11  INFO Propagator: Events aren't parametrised.
# 2026.07.28 17:02:11  INFO Propagator: Printing 7 events...
#
# 2026.07.28 17:02:11  INFO PlotGenerator: Defining histogram holders...
# 2026.07.28 17:02:11  INFO LikelihoodInterface: Samples breakdown:
# ┌──────────────────────────────────────────────────────────┬──────────────────┬─────────────────┬──────────────────┬─────────────────┬───────────┐
# │                                                   Sample │ Model (# binned) │ Data (# binned) │ Model (weighted) │ Data (weighted) │ Diff. (%) │
# ├──────────────────────────────────────────────────────────┼──────────────────┼─────────────────┼──────────────────┼─────────────────┼───────────┤
# │                FHC FGD1 #nu_{#mu} CC 0#pi 0p 0#gamma Fwd │            65973 │           65973 │           3280.6 │            3257 │ -0.719372 │
# │                FHC FGD1 #nu_{#mu} CC 0#pi Np 0#gamma Fwd │

# 2026.07.28 17:02:11  INFO LikelihoodInterface:   FHC FGD2 #nu_{#mu} CC Other 0#gamma: 144.926,
# 2026.07.28 17:02:11  INFO LikelihoodInterface:   FHC FGD2 #nu_{#mu} CC #gamma: 168.251,
# 2026.07.28 17:02:11  INFO LikelihoodInterface:   RHC FGD1 Anti #nu_{#mu} CC 0#pi: 243.19,
# 2026.07.28 17:02:11  INFO LikelihoodInterface:   RHC FGD1 Anti #nu_{#mu} CC 1#pi: 80.1444,
# 2026.07.28 17:02:11  INFO LikelihoodInterface:   RHC FGD1 Anti #nu_{#mu} CC Other: 93.1106,
# 2026.07.28 17:02:11  INFO LikelihoodInterface:   RHC FGD2 Anti #nu_{#mu} CC 0#pi: 263.127,
# 2026.07.28 17:02:11  INFO LikelihoodInterface:   RHC FGD2 Anti #nu_{#mu} CC 1#pi: 76.359,
# 2026.07.28 17:02:11  INFO LikelihoodInterface:   RHC FGD2 Anti #nu_{#mu} CC Other: 84.6226,
# 2026.07.28 17:02:11  INFO LikelihoodInterface:   RHC FGD1 #nu_{#mu} (background) CC 0#pi in AntiNu_Mode: 189.011,
# 2026.07.28 17:02:11  INFO LikelihoodInterface:   RHC FGD1 #nu_{#mu} (background) CC 1#pi in AntiNu_Mode: 124.921,
# 2026.07.28 17:02:11  INFO LikelihoodInterface:   RHC FGD1 #nu_{#mu} (background) CC Other in AntiNu_Mode: 83.1711,
# 2026.07.28 17:02:11  INFO LikelihoodInterface:   RHC FGD2 #nu_{#mu} (background) CC 0#pi in AntiNu_Mode: 166.383,
# 2026.07.28 17:02:11  INFO LikelihoodInterface:   RHC FGD2 #nu_{#mu} (background) CC 1#pi  in AntiNu_Mode: 83.0694,
# 2026.07.28 17:02:11  INFO LikelihoodInterface:   RHC FGD2 #nu_{#mu} (background) CC Other  in AntiNu_Mode: 84.4779
# 2026.07.28 17:02:11  INFO LikelihoodInterface: }
# 2026.07.28 17:02:11  INFO LikelihoodInterface: Penalty likelihood = 0 = sum of: {
# 2026.07.28 17:02:11  INFO LikelihoodInterface:   Flux Systematics: 0
# 2026.07.28 17:02:11  INFO LikelihoodInterface: }
# 2026.07.28 17:02:11  INFO LikelihoodInterface: LikelihoodInterface initialized.
# 2026.07.28 17:02:11  WARN ParameterScanner: Initializing ParameterScanner...
# 2026.07.28 17:02:11  WARN ParameterScanner: ParameterScanner initialized.
# 2026.07.28 17:02:11  INFO MinimizerBase: Initializing MinimizerBase...
# 2026.07.28 17:02:11  INFO MinimizerBase: Nb minimizer parameters: 5
# 2026.07.28 17:02:11  INFO MinimizerBase: MinimizerBase initialized.
# 2026.07.28 17:02:11  INFO RootMinimizer: Initializing RootMinimizer...
# 2026.07.28 17:02:11  INFO RootMinimizer: Tolerance is set to: 1
# 2026.07.28 17:02:11  INFO RootMinimizer: The minimizer will run until it reaches an Estimated Distance to Minimum (EDM) of: 0.001
# 2026.07.28 17:02:11  INFO RootMinimizer: EDM per degree of freedom is: 2.41546e-07
# 2026.07.28 17:02:11  INFO RootMinimizer: Defining minimizer as: Minuit2/Migrad
# 2026.07.28 17:02:11  INFO RootMinimizer: RootMinimizer initialized.

# %%
sampleIndex = 0
eventIndex = 0

sample = gundam.modelSamples[sampleIndex].handle
events = sample.getEventList()
event = events[eventIndex]

indices = event.getIndices()

print(f"Sample index: {sampleIndex}")
print(f"Sample name:  {sample.getName()}")
print(f"Event index:  {eventIndex}")
print(f"Event weight: {event.getEventWeight():.8g}")
print(f"Entry:        {indices.entry}")
print(f"Bin:          {indices.bin}")

print(event.getSummary())
# Out:
# Sample index: 0
# Sample name:  FHC FGD1 #nu_{#mu} CC 0#pi 0p 0#gamma Fwd
# Event index:  0
# Event weight: 0.050692335
# Entry:        14
# Bin:          100
# Indices{dataset(0), entry(14 / 0-14), sample(0), bin(100)}
# Weights{base(0.0506923), current(0.0506923)}
# Variables{
#   { name: Pmu, value: 1184.51 }
#   { name: CosThetamu, value: 0.844175 }
#   { name: ReactionCode, value: 2 }
# }

# %%
variables = event.getVariables()
varList = variables.getVarList()

print(f"Number of variables: {len(varList)}")
for index, variable in enumerate(varList[:10]):
    print(f"{index:3d}: {variable.getVarAsDouble():.8g}")
# Out:
# Number of variables: 3
#   0: 1184.5121
#   1: 0.84417462
#   2: 2

# %%
names = variables.getNameList()
for index, name in enumerate(names):
    print(f"{index:3d}: {name}, {variables.fetchVariable(name).getVarAsDouble():.8g}")
# Out:
#   0: Pmu, 1184.5121
#   1: CosThetamu, 0.84417462
#   2: ReactionCode, 2
