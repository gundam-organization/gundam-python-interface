# %% [markdown]
# # First event inspection
#
# Load a GUNDAM engine and inspect the first event of the first model sample.

# %%
nCpuThreads = 3
gundamLibPath = "/Users/nadrino/Documents/Work/Install/gundam/lib"
workDir = "/Users/nadrino/Documents/Work/Output/results/gundam/GundamInputOA2024"
configPath = "configOA2024.yaml"
overrideList = [
    "override/v12ProdRun45.yaml",
    "override/onlyFlux5.yaml",
    "override/noEigen.yaml",
]
dataType = "Toy"  # "Asimov", "Toy", or "RealData"
seed = 12345

# %%
import sys
from pathlib import Path

import numpy as np

repoRoot = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
srcPath = repoRoot / "src"
if srcPath.exists() and str(srcPath) not in sys.path:
    sys.path.insert(0, str(srcPath))

from gundam_interface import GundamInterface, GundamLoader, GundamRuntime

# %%
np.random.seed(seed)

runtime = GundamRuntime(
    loader=GundamLoader(gundamLibPath=gundamLibPath),
    workDir=workDir,
    nCpuThreads=nCpuThreads,
    configPath=configPath,
    overrideList=overrideList,
    dataType=dataType,
    randomSeed=seed,
)

runtime.toDict(includeConfigJsonString=False)
# Out:
# {'nCpuThreads': 3,
#  'workDir': '/Users/nadrino/Documents/Work/Output/results/gundam/GundamInputOA2024',
#  'dataType': 'Toy',
#  'loader': {'moduleName': 'GUNDAM',
#   'gundamLibPath': '/Users/nadrino/Documents/Work/Install/gundam/lib'},
#  'randomSeed': 12345,
#  'configPath': 'configOA2024.yaml',
#  'overrideList': ['override/v12ProdRun45.yaml',
#   'override/onlyFlux5.yaml',
#   'override/noEigen.yaml']}

# %%
gundam = GundamInterface(runtime)
gundam.configure()
gundam.initialize()
# Out:
# 12345
# 2026.07.28 16:44:50  INFO ConfigUtils: Reading config file: /Users/nadrino/Documents/Work/Output/results/gundam/GundamInputOA2024/configOA2024.yaml
# 2026.07.28 16:44:50  INFO ConfigUtils: Overriding config with "/Users/nadrino/Documents/Work/Output/results/gundam/GundamInputOA2024/override/v12ProdRun45.yaml"
# 2026.07.28 16:44:50  WARN ConfigUtils:   Added: fitterEngineConfig/propagatorConfig/dataSetList/0(name:"ND280")/mc/filePathList
# 2026.07.28 16:44:50  WARN ConfigUtils:   Added: fitterEngineConfig/propagatorConfig/dataSetList/0(name:"ND280")/data/0(name:"data")/filePathList
# 2026.07.28 16:44:50  INFO ConfigUtils: Overriding config with "/Users/nadrino/Documents/Work/Output/results/gundam/GundamInputOA2024/override/onlyFlux5.yaml"
# 2026.07.28 16:44:50  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"Flux Systematics")/isEnabled: true -> false
# 2026.07.28 16:44:50  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"ND280 Detector Systematics (variations parameters)")/isEnabled: true -> false
# 2026.07.28 16:44:50  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"ND280 Detector Systematics (splined detector parameters)")/isEnabled: true -> false
# 2026.07.28 16:44:50  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"Cross-Section Systematics FSI parameters")/isEnabled: true -> false
# 2026.07.28 16:44:50  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"Cross-Section Systematics")/isEnabled: true -> false
# 2026.07.28 16:44:50  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"Cross-Section (binned) Systematics")/isEnabled: true -> false
# 2026.07.28 16:44:50  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/1(name:"Flux Systematics")/isEnabled: false -> true
# 2026.07.28 16:44:50  WARN ConfigUtils:   Added: fitterEngineConfig/propagatorConfig/parameterSetListConfig/1(name:"Flux Systematics")/enableOnlyParameters
# 2026.07.28 16:44:50  INFO ConfigUtils: Overriding config with "/Users/nadrino/Documents/Work/Output/results/gundam/GundamInputOA2024/override/noEigen.yaml"
# 2026.07.28 16:44:50  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"Flux Systematics")/useEigenDecompInFit: true -> false
# 2026.07.28 16:44:50  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"ND280 Detector Systematics (variations parameters)")/useEigenDecompInFit: true -> false
# 2026.07.28 16:44:50  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"ND280 Detector Systematics (splined detector parameters)")/useEigenDecompInFit: false -> false
# 2026.07.28 16:44:50  WARN ConfigUtils:   Override: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"Cross-Section Systematics FSI parameters")/useEigenDecompInFit: true -> false
# 2026.07.28 16:44:50  WARN ConfigUtils:   Added: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"Cross-Section Systematics")/useEigenDecompInFit -> false
# 2026.07.28 16:44:50  WARN ConfigUtils:   Added: fitterEngineConfig/propagatorConfig/parameterSetListConfig/0(name:"Cross-Section (binned) Systematics")/useEigenDecompInFit -> false
# 2026.07.28 16:44:50  WARN ConfigUtils: /fitterEngineConfig: key "allParamVariations" has been renamed. Use "paramVariationsSigmas" instead.
# 2026.07.28 16:44:50  WARN ConfigUtils: /fitterEngineConfig: key "scanConfig" has been renamed. Use "parameterScannerConfig" instead.
# 2026.07.28 16:44:50 ALERT ConfigUtils: /fitterEngineConfig: field "propagatorConfig" should be moved to: fitterEngineConfig/likelihoodInterfaceConfig/propagatorConfig
# 2026.07.28 16:44:50  WARN ConfigUtils: /fitterEngineConfig/minimizerConfig: key "max_iter" has been renamed. Use "maxIterations" instead.
# 2026.07.28 16:44:50  WARN ConfigUtils: /fitterEngineConfig/minimizerConfig: key "max_fcn" has been renamed. Use "maxFcnCalls" instead.
# 2026.07.28 16:44:50 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig: key "showEventBreakdownBeforePrior" has an invalid name. It won't be recognized by GUNDAM.
# 2026.07.28 16:44:50  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig: key "fitSampleSetConfig" has been renamed. Use "sampleSetConfig" instead.
# 2026.07.28 16:44:50 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig: field "parameterSetListConfig" should be moved to: parametersManagerConfig/parameterSetList
# 2026.07.28 16:44:50 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig: field "plotGeneratorConfig" should be moved to: likelihoodInterfaceConfig/plotGeneratorConfig
# 2026.07.28 16:44:50 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig: field "scanConfig" should be moved to: fitterEngineConfig/scanConfig
# 2026.07.28 16:44:50 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig: field "eventTreeWriter" should be moved to: likelihoodInterfaceConfig/eventTreeWriter
# 2026.07.28 16:44:50 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig: field "dataSetList" should be moved to: likelihoodInterfaceConfig/dataSetList
# 2026.07.28 16:44:50 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig/fitSampleSetConfig: key "dataEventType" has an invalid name. It won't be recognized by GUNDAM.
# 2026.07.28 16:44:50  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/fitSampleSetConfig: key "fitSampleList" has been renamed. Use "sampleList" instead.
# 2026.07.28 16:44:50 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig/fitSampleSetConfig: field "llhStatFunction" should be moved to: likelihoodInterfaceConfig/jointProbabilityConfig/type
# 2026.07.28 16:44:50 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig/fitSampleSetConfig: field "llhConfig" should be moved to: likelihoodInterfaceConfig/jointProbabilityConfig
# 2026.07.28 16:44:50  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/fitSampleSetConfig/fitSampleList/0: key "selectionCuts" has been renamed. Use "selectionCutStr" instead.
# 2026.07.28 16:44:50  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/0: key "covarianceMatrixFilePath" has been renamed. Use "parameterDefinitionFilePath" instead.
# 2026.07.28 16:44:50  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/0: key "covarianceMatrixTMatrixD" has been renamed. Use "covarianceMatrix" instead.
# 2026.07.28 16:44:50  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/0: key "useEigenDecompInFit" has been renamed. Use "enableEigenDecomp" instead.
# 2026.07.28 16:44:50 ALERT GenericToolbox.Root.h:119/<lambda>: Found a non-symmetric element m[0][6]: diff = -2.1684e-19
# 2026.07.28 16:44:50 ALERT GenericToolbox.Root.h:130/toTMatrixTSym: Conversion to symmetric matrix by averaging opposite elements...
# 2026.07.28 16:44:50 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/1: key "useOnlyOneParameterPerEvent" has an invalid name. It won't be recognized by GUNDAM.
# 2026.07.28 16:44:50  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/1: key "allowPca" has been renamed. Use "enablePca" instead.
# 2026.07.28 16:44:50  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/1: key "printDialSetsSummary" has been renamed. Use "printDialSetSummary" instead.
# 2026.07.28 16:44:50  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/1: key "parameterPriorTVectorD" has been renamed. Use "parameterPriorValueList" instead.
# 2026.07.28 16:44:50  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/1: key "eigenSvdThreshold" has been renamed. Use "eigenValueThreshold" instead.
# 2026.07.28 16:44:50 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/2: key "atLeastOneDialPerEvent" has an invalid name. It won't be recognized by GUNDAM.
# 2026.07.28 16:44:50  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/2: key "parameterNameTObjArray" has been renamed. Use "parameterNameList" instead.
# 2026.07.28 16:44:50  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/2: key "parameterLowerBoundsTVectorD" has been renamed. Use "parameterLowerBoundsList" instead.
# 2026.07.28 16:44:50  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/parameterSetListConfig/2: key "parameterUpperBoundsTVectorD" has been renamed. Use "parameterUpperBoundsList" instead.
# 2026.07.28 16:44:50  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/dataSetList/0: key "mc" has been renamed. Use "model" instead.
# 2026.07.28 16:44:50  WARN ConfigUtils:   Added: name -> "data"
# 2026.07.28 16:44:50  WARN ConfigUtils:   Added: tree -> "sample_sum"
# 2026.07.28 16:44:50  WARN ConfigUtils:   Added: filePathList
# 2026.07.28 16:44:50  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/plotGeneratorConfig: key "varDictionnaries" has been renamed. Use "varDictionaries" instead.
# 2026.07.28 16:44:50  WARN ConfigUtils: /fitterEngineConfig/propagatorConfig/plotGeneratorConfig/varDictionnaries/0/dictionary/0: key "color" has been renamed. Use "colorRoot" instead.
# 2026.07.28 16:44:50 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig/eventTreeWriter: key "dialWriterConfig" has an invalid name. It won't be recognized by GUNDAM.
# 2026.07.28 16:44:50  WARN EventTreeWriter: (virtual void EventTreeWriter::configureImpl()): Disabled EventTreeWriter.
# 2026.07.28 16:44:50 ALERT ConfigUtils: /fitterEngineConfig/propagatorConfig: key "showEventBreakdownBeforePrior" was ignored while parsing config. Is is context dependent option?
# 2026.07.28 16:44:50  INFO ParameterSet: Stripping the matrix from fixed/disabled parameters...
# 2026.07.28 16:44:50  INFO ParameterSet: 5 effective parameters were defined in set: Flux Systematics
# 2026.07.28 16:44:50  INFO ParameterSet: Computing inverse of the stripped covariance matrix: 5x5
# 2026.07.28 16:44:50  INFO ParametersManager: 5 enabled parameters in Flux Systematics
# 2026.07.28 16:44:50  INFO ParametersManager: Total number of parameters: 5
# 2026.07.28 16:44:50  INFO ParametersManager: Building global covariance matrix (5x5)
# 2026.07.28 16:44:50  INFO ParameterSet: Stripping the matrix from fixed/disabled parameters...
# 2026.07.28 16:44:50  INFO ParameterSet: 5 effective parameters were defined in set: Flux Systematics
# 2026.07.28 16:44:50  INFO ParameterSet: Computing inverse of the stripped covariance matrix: 5x5
# 2026.07.28 16:44:50  INFO ParametersManager: 5 enabled parameters in Flux Systematics
# 2026.07.28 16:44:50  INFO ParametersManager: Total number of parameters: 5
# 2026.07.28 16:44:50  INFO ParametersManager: Building global covariance matrix (5x5)
#
# 2026.07.28 16:44:50  INFO Propagator: Printing propagator configuration:
# 2026.07.28 16:44:50  INFO SampleSet: 32 samples are defined:
# ┌──────────────────────────────────────────────────────────┬───────────────────────┬────────────┐
# │                                                     Name │             Selection │ Nb of bins │
# ├──────────────────────────────────────────────────────────┼───────────────────────┼────────────┤
# │                FHC FGD1 #nu_{#mu} CC 0#pi 0p 0#gamma Fwd │ SelectedSample == 131 │        252 │
# │                FHC FGD1 #nu_{#mu} CC 0#pi Np 0#gamma Fwd │ SelectedSample == 132 │        224 │
# │                  FGD1 numuCC 0#pi 0#gamma No Protons Bwd │ SelectedSample == 133 │         30 │
# │               FGD1 numuCC 0#pi Bwd 0#gamma N Protons Bwd │ SelectedSample == 134 │         60 │
# │                   FGD1 numuCC 0#pi 0#gamma No Protons HA │ SelectedSample == 139 │         96 │
# │                    FGD1 numuCC 0#pi 0#gamma N Protons HA │ SelectedSample == 140 │        102 │
# │                   FHC FGD1 #nu_{#mu} CC 1#pi 0#gamma Fwd │ SelectedSample == 116 │        140 │
# │                            FGD1 numuCC 1Pi 0#gamma HAFwd │ SelectedSample == 122 │         30 │
# │                      FHC FGD1 #nu_{#mu} CC Other 0#gamma │ SelectedSample == 117 │        144 │
# │                             FHC FGD1 #nu_{#mu} CC #gamma │ SelectedSample == 127 │        182 │
# │                FHC FGD2 #nu_{#mu} CC 0#pi 0p 0#gamma Fwd │ SelectedSample == 157 │        252 │
# │                FHC FGD2 #nu_{#mu} CC 0#pi Np 0#gamma Fwd │ SelectedSample == 158 │        168 │
# │                  FGD2 numuCC 0#pi 0#gamma No Protons Bwd │ SelectedSample == 159 │         18 │
# │                   FGD2 numuCC 0#pi 0#gamma N Protons Bwd │ SelectedSample == 160 │         54 │
# │                   FGD2 numuCC 0#pi HA 0#gamma No Protons │ SelectedSample == 165 │        100 │
# │                    FGD2 numuCC 0#pi 0#gamma N Protons HA │ SelectedSample == 166 │         78 │
# │                   FHC FGD2 #nu_{#mu} CC 1#pi 0#gamma Fwd │ SelectedSample == 142 │        160 │
# │                            FGD2 numuCC 1Pi 0#gamma HAFwd │ SelectedSample == 148 │         30 │
# │                      FHC FGD2 #nu_{#mu} CC Other 0#gamma │ SelectedSample == 143 │        152 │
# │                             FHC FGD2 #nu_{#mu} CC #gamma │ SelectedSample == 153 │        153 │
# │                          RHC FGD1 Anti #nu_{#mu} CC 0#pi │  SelectedSample == 59 │        240 │
# │                          RHC FGD1 Anti #nu_{#mu} CC 1#pi │  SelectedSample == 60 │        110 │
# │                         RHC FGD1 Anti #nu_{#mu} CC Other │  SelectedSample == 61 │        110 │
# │                          RHC FGD2 Anti #nu_{#mu} CC 0#pi │  SelectedSample == 69 │        242 │
# │                          RHC FGD2 Anti #nu_{#mu} CC 1#pi │  SelectedSample == 70 │         88 │
# │                         RHC FGD2 Anti #nu_{#mu} CC Other │  SelectedSample == 71 │         88 │
# │   RHC FGD1 #nu_{#mu} (background) CC 0#pi in AntiNu_Mode │  SelectedSample == 79 │        210 │
# │   RHC FGD1 #nu_{#mu} (background) CC 1#pi in AntiNu_Mode │  SelectedSample == 80 │        126 │
# │  RHC FGD1 #nu_{#mu} (background) CC Other in AntiNu_Mode │  SelectedSample == 81 │        126 │
# │   RHC FGD2 #nu_{#mu} (background) CC 0#pi in AntiNu_Mode │  SelectedSample == 85 │        182 │
# │  RHC FGD2 #nu_{#mu} (background) CC 1#pi  in AntiNu_Mode │  SelectedSample == 86 │         88 │
# │ RHC FGD2 #nu_{#mu} (background) CC Other  in AntiNu_Mode │  SelectedSample == 87 │        105 │
# └──────────────────────────────────────────────────────────┴───────────────────────┴────────────┘
# 2026.07.28 16:44:50  INFO ParametersManager: 1 parameter sets defined.
# 2026.07.28 16:44:50  INFO ParameterSet: Flux Systematics has 5 defined parameters:
# ┌───────┬───────┬──────────┬──────────────┐
# │ Title │ Prior │   StdDev │       Limits │
# ├───────┼───────┼──────────┼──────────────┤
# │    #0 │     1 │ 0.059244 │ [-inf, +inf] │
# │    #1 │     1 │ 0.052535 │ [-inf, +inf] │
# │    #2 │     1 │ 0.052934 │ [-inf, +inf] │
# │    #3 │     1 │ 0.051455 │ [-inf, +inf] │
# │    #4 │     1 │ 0.073820 │ [-inf, +inf] │
# └───────┴───────┴──────────┴──────────────┘
# 2026.07.28 16:44:50  INFO DialManager: Dial manager has 1 dial collections:
# ┌──────────────────┬──────┬─────────┐
# │  Dial Collection │ Type │ Options │
# ├──────────────────┼──────┼─────────┤
# │ Flux Systematics │ Norm │         │
# └──────────────────┴──────┴─────────┘
# 2026.07.28 16:44:50  INFO DialManager:       : Event-by-event dials.
#
#
# 2026.07.28 16:44:50  INFO LikelihoodInterface: Loading model...
# 2026.07.28 16:44:50  INFO LikelihoodInterface: Loading datasets...
# 2026.07.28 16:44:50  INFO DataDispenser: Loading dataset: ND280/Asimov
# 2026.07.28 16:44:50  INFO DataDispenser: Fetching samples to fill...
# 2026.07.28 16:44:50  INFO DataDispenser: Variable dictionary: {
# 2026.07.28 16:44:50  INFO DataDispenser:   { Pmu: PmuAdjusted }
# 2026.07.28 16:44:50  INFO DataDispenser: }
# 2026.07.28 16:44:50  INFO DataDispenser: Poll all objects for requested variables...
# 2026.07.28 16:44:50  INFO DataDispenser: Selecting dial collections...
# 2026.07.28 16:44:50  INFO DataDispenser: DialCollection requests for indexing: { "isRHC", "NeutrinoCode", "Enu" }
# 2026.07.28 16:44:50  INFO DataDispenser: Samples variable request for indexing: { "CosThetamu", "Pmu" }
# 2026.07.28 16:44:50  INFO DataDispenser: PlotGenerator variable request for storage: { "Pmu", "CosThetamu", "ReactionCode" }
# 2026.07.28 16:44:50  INFO DataDispenser: Additional var requests for storage:{ }
# 2026.07.28 16:44:50  INFO DataDispenser: Vars requested for storage: { "Pmu", "CosThetamu", "ReactionCode" }
# 2026.07.28 16:44:50  INFO DataDispenser: Performing event selection...
# 2026.07.28 16:44:50  INFO DataDispenser: Event selection...
# 2026.07.28 16:44:50  INFO DataDispenser: Opening ROOT files containing events...
# 2026.07.28 16:44:50  INFO DataDispenser:   /Users/nadrino/Documents/Work/Output/results/gundam/common/OA2024/ND280/Inputs/Splines/XSecAndNDSyst/P7/v12_Highland_3.22.4/MC_mirrored/run4wMCsplines.root
# 2026.07.28 16:44:50  INFO DataDispenser:   /Users/nadrino/Documents/Work/Output/results/gundam/common/OA2024/ND280/Inputs/Splines/XSecAndNDSyst/P7/v12_Highland_3.22.4/MC_mirrored/run5MCsplines.root
# 2026.07.28 16:44:50  INFO DataDispenser:   /Users/nadrino/Documents/Work/Output/results/gundam/common/OA2024/ND280/Inputs/Splines/XSecAndNDSyst/P7/v12_Highland_3.22.4/Sand/runFHCsand4wSplines.root
# 2026.07.28 16:44:50  INFO DataDispenser:   /Users/nadrino/Documents/Work/Output/results/gundam/common/OA2024/ND280/Inputs/Splines/XSecAndNDSyst/P7/v12_Highland_3.22.4/Sand/runRHCsand5Splines.root
# 2026.07.28 16:44:50  INFO DataDispenser: Will read 455803 event entries.
# 2026.07.28 16:44:50  INFO DataDispenser: Selection variable requests: { "passedPsyche", "isConsecutiveIdenticalEvent", "SelectedSample" }
# 2026.07.28 16:44:50  INFO DataDispenser: Global selection cut: "((passedPsyche * (!isConsecutiveIdenticalEvent)))"
# 2026.07.28 16:44:50  INFO DataDispenser: Read from disk:      27B (     9KB/s) / CPU efficiency:  36%
# 2026.07.28 16:44:50  INFO DataDispenser: Performing event selection on ND280/Asimov...   0% (    2 it/s)
#
# 2026.07.28 16:44:50  INFO DataDispenser: Read from disk: 364.797K (11.0536M/s) / CPU efficiency: 111%
# 2026.07.28 16:44:50  INFO DataDispenser: Performing event selection on ND280/Asimov...   9% (1228K it/s)
#
# 2026.07.28 16:44:50  INFO DataDispenser: Read from disk: 776.547K (12.4773M/s) / CPU efficiency: 122%
# 2026.07.28 16:44:50  INFO DataDispenser: Performing event selection on ND280/Asimov...  19% (1386K it/s)
#
# 2026.07.28 16:44:50  INFO DataDispenser: Read from disk: 1.19459M (12.6679M/s) / CPU efficiency:  75%
# 2026.07.28 16:44:50  INFO DataDispenser: Performing event selection on ND280/Asimov...  29% (1407K it/s)
#
# 2026.07.28 16:44:50  INFO DataDispenser: Read from disk: 1.61981M (12.8855M/s) / CPU efficiency: 100%
# 2026.07.28 16:44:50  INFO DataDispenser: Performing event selection on ND280/Asimov...  39% (1431K it/s)
#
# 2026.07.28 16:44:50  INFO DataDispenser: Read from disk: 2.02352M (12.2335M/s) / CPU efficiency: 111%
# 2026.07.28 16:44:50  INFO DataDispenser: Performing event selection on ND280/Asimov...  49% (1359K it/s)
#
# 2026.07.28 16:44:50  INFO DataDispenser: Read from disk: 2.44995M (12.9224M/s) / CPU efficiency: 111%
# 2026.07.28 16:44:50  INFO DataDispenser: Performing event selection on ND280/Asimov...  60% (1435K it/s)
#
# 2026.07.28 16:44:50  INFO DataDispenser: Read from disk: 2.87566M (12.9003M/s) / CPU efficiency:  75%
# 2026.07.28 16:44:50  INFO DataDispenser: Performing event selection on ND280/Asimov...  70% (1433K it/s)
#
# 2026.07.28 16:44:50  INFO DataDispenser: Read from disk: 3.2859MB (12.4315M/s) / CPU efficiency: 122%
# 2026.07.28 16:44:50  INFO DataDispenser: Performing event selection on ND280/Asimov...  80% (1381K it/s)
#
# 2026.07.28 16:44:50  INFO DataDispenser: Read from disk: 3.68134M (11.9831M/s) / CPU efficiency: 111%
# 2026.07.28 16:44:50  INFO DataDispenser: Performing event selection on ND280/Asimov...  90% (1331K it/s)
#
# 2026.07.28 16:44:50  INFO DataDispenser: Read from disk: 4.09142M (12.4265M/s) / CPU efficiency:  66%
# 2026.07.28 16:44:50  INFO DataDispenser: Performing event selection on ND280/Asimov... 100% (1380K it/s)
# 2026.07.28 16:44:50  INFO DataDispenser: Merging thread results...
# 2026.07.28 16:44:50  INFO DataDispenser: Freeing up thread buffers...
# 2026.07.28 16:44:50  INFO DataDispenser: Events passing selection cuts:
# ┌──────────────────────────────────────────────────────────┬───────────────────────┬─────────────┐
# │                                                   Sample │             Selection │ # of events │
# ├──────────────────────────────────────────────────────────┼───────────────────────┼─────────────┤
# │                FHC FGD1 #nu_{#mu} CC 0#pi 0p 0#gamma Fwd │ SelectedSample == 131 │       69198 │
# │                FHC FGD1 #nu_{#mu} CC 0#pi Np 0#gamma Fwd │ SelectedSample == 132 │       27487 │
# │                  FGD1 numuCC 0#pi 0#gamma No Protons Bwd │ SelectedSample == 133 │        2329 │
# │               FGD1 numuCC 0#pi Bwd 0#gamma N Protons Bwd │ SelectedSample == 134 │        1889 │
# │                   FGD1 numuCC 0#pi 0#gamma No Protons HA │ SelectedSample == 139 │        8668 │
# │                    FGD1 numuCC 0#pi 0#gamma N Protons HA │ SelectedSample == 140 │        6528 │
# │                   FHC FGD1 #nu_{#mu} CC 1#pi 0#gamma Fwd │ SelectedSample == 116 │       18408 │
# │                            FGD1 numuCC 1Pi 0#gamma HAFwd │ SelectedSample == 122 │        1500 │
# │                      FHC FGD1 #nu_{#mu} CC Other 0#gamma │ SelectedSample == 117 │        3359 │
# │                             FHC FGD1 #nu_{#mu} CC #gamma │ SelectedSample == 127 │       38945 │
# │                FHC FGD2 #nu_{#mu} CC 0#pi 0p 0#gamma Fwd │ SelectedSample == 157 │       72819 │
# │                FHC FGD2 #nu_{#mu} CC 0#pi Np 0#gamma Fwd │ SelectedSample == 158 │       20536 │
# │                  FGD2 numuCC 0#pi 0#gamma No Protons Bwd │ SelectedSample == 159 │        1739 │
# │                   FGD2 numuCC 0#pi 0#gamma N Protons Bwd │ SelectedSample == 160 │         821 │
# │                   FGD2 numuCC 0#pi HA 0#gamma No Protons │ SelectedSample == 165 │        8089 │
# │                    FGD2 numuCC 0#pi 0#gamma N Protons HA │ SelectedSample == 166 │        3788 │
# │                   FHC FGD2 #nu_{#mu} CC 1#pi 0#gamma Fwd │ SelectedSample == 142 │       14651 │
# │                            FGD2 numuCC 1Pi 0#gamma HAFwd │ SelectedSample == 148 │         908 │
# │                      FHC FGD2 #nu_{#mu} CC Other 0#gamma │ SelectedSample == 143 │        3254 │
# │                             FHC FGD2 #nu_{#mu} CC #gamma │ SelectedSample == 153 │       36076 │
# │                          RHC FGD1 Anti #nu_{#mu} CC 0#pi │  SelectedSample == 59 │       26759 │
# │                          RHC FGD1 Anti #nu_{#mu} CC 1#pi │  SelectedSample == 60 │        2042 │
# │                         RHC FGD1 Anti #nu_{#mu} CC Other │  SelectedSample == 61 │        3881 │
# │                          RHC FGD2 Anti #nu_{#mu} CC 0#pi │  SelectedSample == 69 │       26325 │
# │                          RHC FGD2 Anti #nu_{#mu} CC 1#pi │  SelectedSample == 70 │        1914 │
# │                         RHC FGD2 Anti #nu_{#mu} CC Other │  SelectedSample == 71 │        3598 │
# │   RHC FGD1 #nu_{#mu} (background) CC 0#pi in AntiNu_Mode │  SelectedSample == 79 │        8786 │
# │   RHC FGD1 #nu_{#mu} (background) CC 1#pi in AntiNu_Mode │  SelectedSample == 80 │        3059 │
# │  RHC FGD1 #nu_{#mu} (background) CC Other in AntiNu_Mode │  SelectedSample == 81 │        2732 │
# │   RHC FGD2 #nu_{#mu} (background) CC 0#pi in AntiNu_Mode │  SelectedSample == 85 │        8901 │
# │  RHC FGD2 #nu_{#mu} (background) CC 1#pi  in AntiNu_Mode │  SelectedSample == 86 │        2489 │
# │ RHC FGD2 #nu_{#mu} (background) CC Other  in AntiNu_Mode │  SelectedSample == 87 │        2680 │
# ├──────────────────────────────────────────────────────────┼───────────────────────┼─────────────┤
# │                                                    Total │                       │      434158 │
# └──────────────────────────────────────────────────────────┴───────────────────────┴─────────────┘
# 2026.07.28 16:44:50  INFO DataDispenser: Pre-allocating memory...
# 2026.07.28 16:44:51  INFO DataDispenser: Reserving event memory...
# ┌──────────────────────────────────────────────────────────┬─────────────┬───────────┐
# │                                                   Sample │ # of events │    Memory │
# ├──────────────────────────────────────────────────────────┼─────────────┼───────────┤
# │                FHC FGD1 #nu_{#mu} CC 0#pi 0p 0#gamma Fwd │       69198 │ 11.9021MB │
# │                FHC FGD1 #nu_{#mu} CC 0#pi Np 0#gamma Fwd │       27487 │ 4.72776MB │
# │                  FGD1 numuCC 0#pi 0#gamma No Protons Bwd │        2329 │ 400.588KB │
# │               FGD1 numuCC 0#pi Bwd 0#gamma N Protons Bwd │        1889 │ 324.908KB │
# │                   FGD1 numuCC 0#pi 0#gamma No Protons HA │        8668 │  1.4909MB │
# │                    FGD1 numuCC 0#pi 0#gamma N Protons HA │        6528 │ 1.12282MB │
# │                   FHC FGD1 #nu_{#mu} CC 1#pi 0#gamma Fwd │       18408 │ 3.16618MB │
# │                            FGD1 numuCC 1Pi 0#gamma HAFwd │        1500 │     258KB │
# │                      FHC FGD1 #nu_{#mu} CC Other 0#gamma │        3359 │ 577.748KB │
# │                             FHC FGD1 #nu_{#mu} CC #gamma │       38945 │ 6.69854MB │
# │                FHC FGD2 #nu_{#mu} CC 0#pi 0p 0#gamma Fwd │       72819 │ 12.5249MB │
# │                FHC FGD2 #nu_{#mu} CC 0#pi Np 0#gamma Fwd │       20536 │ 3.53219MB │
# │                  FGD2 numuCC 0#pi 0#gamma No Protons Bwd │        1739 │ 299.108KB │
# │                   FGD2 numuCC 0#pi 0#gamma N Protons Bwd │         821 │ 141.212KB │
# │                   FGD2 numuCC 0#pi HA 0#gamma No Protons │        8089 │ 1.39131MB │
# │                    FGD2 numuCC 0#pi 0#gamma N Protons HA │        3788 │ 651.536KB │
# │                   FHC FGD2 #nu_{#mu} CC 1#pi 0#gamma Fwd │       14651 │ 2.51997MB │
# │                            FGD2 numuCC 1Pi 0#gamma HAFwd │         908 │ 156.176KB │
# │                      FHC FGD2 #nu_{#mu} CC Other 0#gamma │        3254 │ 559.688KB │
# │                             FHC FGD2 #nu_{#mu} CC #gamma │       36076 │ 6.20507MB │
# │                          RHC FGD1 Anti #nu_{#mu} CC 0#pi │       26759 │ 4.60255MB │
# │                          RHC FGD1 Anti #nu_{#mu} CC 1#pi │        2042 │ 351.224KB │
# │                         RHC FGD1 Anti #nu_{#mu} CC Other │        3881 │ 667.532KB │
# │                          RHC FGD2 Anti #nu_{#mu} CC 0#pi │       26325 │  4.5279MB │
# │                          RHC FGD2 Anti #nu_{#mu} CC 1#pi │        1914 │ 329.208KB │
# │                         RHC FGD2 Anti #nu_{#mu} CC Other │        3598 │ 618.856KB │
# │   RHC FGD1 #nu_{#mu} (background) CC 0#pi in AntiNu_Mode │        8786 │ 1.51119MB │
# │   RHC FGD1 #nu_{#mu} (background) CC 1#pi in AntiNu_Mode │        3059 │ 526.148KB │
# │  RHC FGD1 #nu_{#mu} (background) CC Other in AntiNu_Mode │        2732 │ 469.904KB │
# │   RHC FGD2 #nu_{#mu} (background) CC 0#pi in AntiNu_Mode │        8901 │ 1.53097MB │
# │  RHC FGD2 #nu_{#mu} (background) CC 1#pi  in AntiNu_Mode │        2489 │ 428.108KB │
# │ RHC FGD2 #nu_{#mu} (background) CC Other  in AntiNu_Mode │        2680 │  460.96KB │
# ├──────────────────────────────────────────────────────────┼─────────────┼───────────┤
# │                                                    Total │      434158 │ 74.6752MB │
# └──────────────────────────────────────────────────────────┴─────────────┴───────────┘
# 2026.07.28 16:44:51  INFO DataDispenser: Filling var index cache for bin edges...
# 2026.07.28 16:44:51  INFO DataDispenser: Reading dataset and loading...
# 2026.07.28 16:44:51  INFO DataDispenser: Nominal weight: "((FluxWeight[0] * PileUpWeight)*(POTWeight)*((DetNomWeight > 10) ? 10: (DetNomWeight < 0 ? 0 : DetNomWeight))*(XsecNomWeight))"
# 2026.07.28 16:44:51  INFO DataDispenser: Loading and indexing...
# 2026.07.28 16:44:51  INFO DataDispenser: Feeding event variables with:
# ┌─────────────────�20�26.07.�─�28�─────────┬───────� 1�─6:44:�51 ��A��LE�RT�� �─DataDispense�r: Select�─e──d e─�vent ��─not in ─�a likelihood histogram bin:
# ��─202──�6��.07.28 16:44:51 ALERT DataDispenser:   Indices{dataset(�─�0),��� en���try(�
# �3040��    05    / 0- 3040    05        Var), siable ample(10)�, bin�� (-1)}
#  202           Expression │
# ├──────�6.0��──�7.28 16:4��─4:5──────────────────┼──────1 ALERT DataDispenser:   W�e���ight�s{bas��e(��0��──.─0──69924�3), c�u�──────�rr�e��nt(1��─�)}�
# ─20�26.��0�7�.28 16:44:51 AL�E�─┤
# │RT  isCon[secu90mtivDeIdataDispenserm: nt  VariabiclealEvent s used in b�in� isningCons{ ecutiveIdCosThetamu: entical0.9Ev64861, enPmtu: 3/B2316. �4�
# │, }
#                 NeutrinoCode │                NeutrinoCode/I │
# │                ReactionCode │                ReactionCode/I │
# │              SelectedSample │              SelectedSample/I │
# │                       isRHC │                       isRHC/I │
# │                passedPsyche │                passedPsyche/I │
# │                  CosThetamu │                  CosThetamu/D │
# │                Det2026.Nom07.28 1We6:44:51 ght5mAL │    ERT          Da   DetNotaDispensemWer: Selectighed evet/D │nt
#  no│    t in a li   k      elihoo  d     hist     ogr amEnu bi �n�  :
#       2     026 .0 7.28 16:44:51 ALERT DataDispenser:   Indices{dataset(0), entry(152204 / 0-152204), sample(0), bin(-1)}
#  2026    .07.28    16:44:51 ALERT DataDispense  Er:   Wnu/D │
# │                   POTWeights{base(0.0577043), current(1)}
# eight │                   POTWeight/D │
# │                PileUpWeight │                PileUp2026.07.28 16:44:51 ALERT DataDispenser:   Variables used in binning{ CosThetamu: 0.997801, Pmu: 102593, }
# Weight/2026.0D │
# │7.28 16   :4    4: 51 AL  E RT  [  90m   PmuDataAdjuDisted �sp��enser       [0   m:        Selected ePventmuAdj not in usted/D �a l�ike�
# �li��     hood         histogram bi  n: Xsec
# NomW20eight │26          .0   7.28   16:4Xs4:e51 cNomWe[3ig5mALERht/T �m��
# � ��           [90      mD        44mtaDispenserPm[0u �m��:        In   dic  es [{dat44maset(PmuAdju0sted), /foentry(rmu304la2 0│9 / 0-3
# �04209), sample�───────────────────(14�), ���bin���(-1���)}
# �202�──────┴───────────────────────────────┘6.07.28 16:44:51 ALERT DataDispenser:   Weight
# s{base(0.0519576), current(1)}
# 2026.07.28 16:44:51 ALERT DataDispenser:   Variables used in binning{ CosThetamu: 0.898291, Pmu: 129451, }
# 2026.07.28 16:44:51 ALERT DataDispenser: Selected event not in a likelihood histogram bin:
# 2026.07.28 16:44:51 ALERT DataDispenser:   Indices{dataset(0), entry(152409 / 0-152409), sample(10), bin(-1)}
# 2026.07.28 16:44:51 ALERT DataDispenser:   Weights{base(0.0560135), current(1)}
# 2026.07.28 16:44:51 ALERT DataDispenser:   Variables used in binning{ CosThetamu: 0.999738, Pmu: 67678.5, }
# 2026.07.28 16:44:51 ALERT DataDispenser:   Further unbinned event warnings will be skipped.
# 2026.07.28 16:44:51 ALERT DataDispenser: Selected event not in a likelihood histogram bin:
# 2026.07.28 16:44:51 ALERT DataDispenser:   Indices{dataset(0), entry(304295 / 0-304295), sample(16), bin(-1)}
# 2026.07.28 16:44:51 ALERT DataDispenser:   Weights{base(0.0526342), current(1)}
# 2026.07.28 16:44:51 ALERT DataDispenser:   Variables used in binning{ CosThetamu: 0

# 2026.07.28 16:44:53  INFO LikelihoodInterface:   FHC FGD1 #nu_{#mu} CC Other 0#gamma: 146.607,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   FHC FGD1 #nu_{#mu} CC #gamma: 152.511,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   FHC FGD2 #nu_{#mu} CC 0#pi 0p 0#gamma Fwd: 269.053,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   FHC FGD2 #nu_{#mu} CC 0#pi Np 0#gamma Fwd: 171.888,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   FGD2 numuCC 0#pi 0#gamma No Protons Bwd: 22.7202,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   FGD2 numuCC 0#pi 0#gamma N Protons Bwd: 45.4733,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   FGD2 numuCC 0#pi HA 0#gamma No Protons: 102.805,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   FGD2 numuCC 0#pi 0#gamma N Protons HA: 74.8615,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   FHC FGD2 #nu_{#mu} CC 1#pi 0#gamma Fwd: 171.851,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   FGD2 numuCC 1Pi 0#gamma HAFwd: 32.514,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   FHC FGD2 #nu_{#mu} CC Other 0#gamma: 144.926,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   FHC FGD2 #nu_{#mu} CC #gamma: 168.251,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   RHC FGD1 Anti #nu_{#mu} CC 0#pi: 243.19,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   RHC FGD1 Anti #nu_{#mu} CC 1#pi: 80.1444,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   RHC FGD1 Anti #nu_{#mu} CC Other: 93.1106,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   RHC FGD2 Anti #nu_{#mu} CC 0#pi: 263.127,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   RHC FGD2 Anti #nu_{#mu} CC 1#pi: 76.359,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   RHC FGD2 Anti #nu_{#mu} CC Other: 84.6226,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   RHC FGD1 #nu_{#mu} (background) CC 0#pi in AntiNu_Mode: 189.011,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   RHC FGD1 #nu_{#mu} (background) CC 1#pi in AntiNu_Mode: 124.921,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   RHC FGD1 #nu_{#mu} (background) CC Other in AntiNu_Mode: 83.1711,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   RHC FGD2 #nu_{#mu} (background) CC 0#pi in AntiNu_Mode: 166.383,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   RHC FGD2 #nu_{#mu} (background) CC 1#pi  in AntiNu_Mode: 83.0694,
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   RHC FGD2 #nu_{#mu} (background) CC Other  in AntiNu_Mode: 84.4779
# 2026.07.28 16:44:53  INFO LikelihoodInterface: }
# 2026.07.28 16:44:53  INFO LikelihoodInterface: Penalty likelihood = 0 = sum of: {
# 2026.07.28 16:44:53  INFO LikelihoodInterface:   Flux Systematics: 0
# 2026.07.28 16:44:53  INFO LikelihoodInterface: }
# 2026.07.28 16:44:53  INFO LikelihoodInterface: LikelihoodInterface initialized.
# 2026.07.28 16:44:53  WARN ParameterScanner: Initializing ParameterScanner...
# 2026.07.28 16:44:53  WARN ParameterScanner: ParameterScanner initialized.
# 2026.07.28 16:44:53  INFO MinimizerBase: Initializing MinimizerBase...
# 2026.07.28 16:44:53  INFO MinimizerBase: Nb minimizer parameters: 5
# 2026.07.28 16:44:53  INFO MinimizerBase: MinimizerBase initialized.
# 2026.07.28 16:44:53  INFO RootMinimizer: Initializing RootMinimizer...
# 2026.07.28 16:44:53  INFO RootMinimizer: Tolerance is set to: 1
# 2026.07.28 16:44:53  INFO RootMinimizer: The minimizer will run until it reaches an Estimated Distance to Minimum (EDM) of: 0.001
# 2026.07.28 16:44:53  INFO RootMinimizer: EDM per degree of freedom is: 2.41546e-07
# 2026.07.28 16:44:53  INFO RootMinimizer: Defining minimizer as: Minuit2/Migrad
# 2026.07.28 16:44:53  INFO RootMinimizer: RootMinimizer initialized.

# %%
sampleIndex = 0
eventIndex = 0

sample = gundam.modelSamples[sampleIndex].handle
events = sample.getEventList()
event = events[eventIndex]

indices = event.getIndices()

print(f"Sample index: {sampleIndex}")
print(f"Sample name:  {sample.getName()}")
print(f"Event index:  {eventIndex}")
print(f"Event weight: {event.getEventWeight():.8g}")
print(f"Entry:        {indices.entry}")
print(f"Bin:          {indices.bin}")

print(event.getSummary())
# Out:
# Sample index: 0
# Sample name:  FHC FGD1 #nu_{#mu} CC 0#pi 0p 0#gamma Fwd
# Event index:  0
# Event weight: 0.050692335
# Entry:        14
# Bin:          100
# Indices{dataset(0), entry(14 / 0-14), sample(0), bin(100)}
# Weights{base(0.0506923), current(0.0506923)}
# Variables{
#   { name: Pmu, value: 1184.51 }
#   { name: CosThetamu, value: 0.844175 }
#   { name: ReactionCode, value: 2 }
# }

# %%
variables = event.getVariables()
varList = variables.getVarList()

print(f"Number of variables: {len(varList)}")
for index, variable in enumerate(varList[:10]):
    print(f"{index:3d}: {variable.getVarAsDouble():.8g}")
# Out:
# Number of variables: 3
#   0: 1184.5121
#   1: 0.84417462
#   2: 2

# %%
names = variables.getNameList()
for index, name in enumerate(names):
    print(f"{index:3d}: {name}, {variables.fetchVariable(name).getVarAsDouble():.8g}")
# Out:
#   0: Pmu, 1184.5121
#   1: CosThetamu, 0.84417462
#   2: ReactionCode, 2
